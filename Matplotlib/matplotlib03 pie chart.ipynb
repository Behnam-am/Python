# %%
import matplotlib.pyplot as plt

# %%
slices = [60,40, 30, 20]
labels = ['Sixty', 'Forty', 'Lbl30', 'Lbl20']
colors = ['#008fd5','#fc4f30','#5eae37','#6d904f']
plt.pie(x=slices,labels=labels, colors=colors, wedgeprops={'edgecolor': 'black'})

# plt.legend(loc='upper left')
plt.show()

# %%
# reset style
plt.rcdefaults()
plt.style.use('fivethirtyeight')

# Language Popularity
slices = [59219, 55466, 47544, 36443, 35917, 31991, 27097, 23030, 20524, 18523, 18017, 7920, 7331, 7201, 5833]
labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java', 'Bash/Shell/PowerShell', 
          'C#', 'PHP', 'C++', 'TypeScript', 'C', 'Other(s):', 'Ruby', 'Go', 'Assembly']

plt.pie(x=slices[:5],labels=labels[:5], wedgeprops={'edgecolor': 'black'})

plt.title('My Pie Chart')
plt.show()

# %%
# reset style
plt.rcdefaults()
plt.style.use('fivethirtyeight')

# Language Popularity
slices = [59219, 55466, 47544, 36443, 35917]
labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java']
explode = [0, 0, 0, .2, 0]

plt.pie(x=slices, labels=labels, explode=explode, shadow=True,
        startangle=90, autopct='%1.1f%%',
        wedgeprops={'edgecolor': 'black'})

plt.title('My Pie Chart')
plt.show()
